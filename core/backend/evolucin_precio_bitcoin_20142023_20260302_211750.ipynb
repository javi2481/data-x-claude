# %%
# Cargar y explorar el dataset de Bitcoin
import pandas as pd

# Ruta al dataset
ruta = './_datasets/Bitcoin_Price_Dataset_2014_2023.csv'

df_btc = pd.read_csv(ruta)

# Mostrar información básica del dataset
print('Shape:', df_btc.shape)
df_btc.info()
df_btc.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 # Ruta al dataset
#       5 ruta = './_datasets/Bitcoin_Price_Dataset_2014_2023.csv'
# ----> 7 df_btc = pd.read_csv(ruta)
#       9 # Mostrar información básica del dataset
#      10 print('Shape:', df_btc.shape)
#
# ...
