# %%
# Cargar y explorar el dataset de ventas
import pandas as pd

df = pd.read_csv('./_datasets/mock_data.csv')
print('Shape:', df.shape)
df.info()
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Cargar y explorar el dataset de ventas
#       2 import pandas as pd
# ----> 4 df = pd.read_csv('./_datasets/mock_data.csv')
#       5 print('Shape:', df.shape)
#       6 df.info()
#
# ...
