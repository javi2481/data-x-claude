# %%
# Carga y exploración inicial del dataset de ventas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Paleta profesional
PALETA = "#386cb0,#fdb462,#7fc97f,#ef3b2c,#984ea3,#a6cee3,#f781bf,#ff7f00"
sns.set_palette(sns.color_palette(PALETA.split(',')))

# Cargar los datos
df = pd.read_csv('./_datasets/mock_data.csv')

# Shape y columnas principales
print("Shape del DataFrame:", df.shape)
display(df.head())
print("\nInformación general:")
df.info()

# Estadísticas descriptivas clave (sólo numéricas)
describe_df = df.describe().T
print("\nEstadísticas descriptivas:")
display(describe_df)

# Revisar valores nulos globales
print("\nValores nulos por columna:")
display(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 11
#       8 sns.set_palette(sns.color_palette(PALETA.split(',')))
#      10 # Cargar los datos
# ---> 11 df = pd.read_csv('./_datasets/mock_data.csv')
#      13 # Shape y columnas principales
#      14 print("Shape del DataFrame:", df.shape)
#
# ...
