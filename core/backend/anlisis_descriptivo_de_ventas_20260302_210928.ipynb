# %%
# Carga y EDA inicial de mock_data.csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Paleta profesional consistente
PALETA = sns.color_palette("deep")

# Cargar el dataset
df = pd.read_csv('./_datasets/mock_data.csv')

# Shape y primeras filas
print('Shape:', df.shape)
display(df.head())

# Info general
df.info()

# Chequeo de nulos por columna
print("\nValores nulos por columna:")
display(df.isnull().sum())

# Estadísticas descriptivas básicas de ventas
if 'ventas' in df.columns:
    print("\nEstadísticas descriptivas de la columna 'ventas':")
    display(df['ventas'].describe())
else:
    print("Columna 'ventas' no encontrada en el dataset.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 11
#       8 PALETA = sns.color_palette("deep")
#      10 # Cargar el dataset
# ---> 11 df = pd.read_csv('./_datasets/mock_data.csv')
#      13 # Shape y primeras filas
#      14 print('Shape:', df.shape)
#
# ...
