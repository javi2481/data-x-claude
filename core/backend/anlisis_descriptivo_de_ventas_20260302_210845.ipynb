# %%
# Cargar y explorar brevemente el dataset para identificar estructura y columnas
import pandas as pd

df = pd.read_csv('./_datasets/mock_data.csv')
df.info()
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Cargar y explorar brevemente el dataset para identificar estructura y columnas
#       2 import pandas as pd
# ----> 4 df = pd.read_csv('./_datasets/mock_data.csv')
#       5 df.info()
#       6 df.head()
#
# ...
