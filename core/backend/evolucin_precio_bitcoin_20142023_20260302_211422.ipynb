# %%
# Exploración inicial del dataset de precio de Bitcoin
import pandas as pd

# Cargar el dataset (suponiendo el encoding más común para csvs)
df = pd.read_csv('./_datasets/Bitcoin_Price_Dataset_2014_2023.csv')

# Analizar estructura y primeras filas
df_shape = df.shape
df_info = df.info()
df_head = df.head()
df_nulls = df.isnull().sum()
df_shape, df_head, df_nulls
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import pandas as pd
#       4 # Cargar el dataset (suponiendo el encoding más común para csvs)
# ----> 5 df = pd.read_csv('./_datasets/Bitcoin_Price_Dataset_2014_2023.csv')
#       7 # Analizar estructura y primeras filas
#       8 df_shape = df.shape
#
# ...
